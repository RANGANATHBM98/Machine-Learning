# %% [markdown]
# ## what type of data formate file does pandas read?
# it give you the capabality to read various type of data formats like
# 1.csv
# 2.json
# 3.html
# 4.excel
# 5.sql
# 6.binary

# %%
import pandas as pd
import numpy as np

# %%
data={
    "Student":["Anurag","vivek","varun","karan"]
}
s=pd.Series(data)

# %%
s.head()
# Out:
# Student    [Anurag, vivek, varun, karan]
# dtype: object

# %%
data={
    "Student":["Amit","Rahul","Priya","Sneha","Karan","Neha","Rohith","Pooja","Arjun","Simran"],
    "Age":[20,21,np.nan,22,20,23,np.nan,21,22,20],
    "Marks":[85,90,78,np.nan,88,92,76,81,np.nan,89],
    "City":["Delhi","Mumbai","Delhi","kolkata",np.nan,"mumbai","Delhi","Chennai","Kolkata",np.nan]
}
df=pd.DataFrame(data)
print(df)
# Out:
#   Student   Age  Marks     City
# 0    Amit  20.0   85.0    Delhi
# 1   Rahul  21.0   90.0   Mumbai
# 2   Priya   NaN   78.0    Delhi
# 3   Sneha  22.0    NaN  kolkata
# 4   Karan  20.0   88.0      NaN
# 5    Neha  23.0   92.0   mumbai
# 6  Rohith   NaN   76.0    Delhi
# 7   Pooja  21.0   81.0  Chennai
# 8   Arjun  22.0    NaN  Kolkata
# 9  Simran  20.0   89.0      NaN

# %%
df.head(6)
# Out:
#   Student   Age  Marks     City
# 0    Amit  20.0   85.0    Delhi
# 1   Rahul  21.0   90.0   Mumbai
# 2   Priya   NaN   78.0    Delhi
# 3   Sneha  22.0    NaN  kolkata
# 4   Karan  20.0   88.0      NaN
# 5    Neha  23.0   92.0   mumbai

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Student  10 non-null     object
#  1   Age      8 non-null      float64
#  2   Marks    8 non-null      float64
#  3   City     8 non-null      object
# dtypes: float64(2), object(2)
# memory usage: 452.0+ bytes

# %%
df.isnull().sum()
# Out:
# Student    0
# Age        2
# Marks      2
# City       2
# dtype: int64

# %%
df['Age'].isnull().sum()
# Out:
# np.int64(2)

# %% [markdown]
# ## write a command to display rows containing only null values

# %%
df[df.isnull().any(axis=1)]
# Out:
#   Student   Age  Marks     City
# 2   Priya   NaN   78.0    Delhi
# 3   Sneha  22.0    NaN  kolkata
# 4   Karan  20.0   88.0      NaN
# 6  Rohith   NaN   76.0    Delhi
# 8   Arjun  22.0    NaN  Kolkata
# 9  Simran  20.0   89.0      NaN

# %%
print(df['Age'].mean())
print(df['Age'].median())
# Out:
# 21.125
# 21.0

# %%
df['Age']=df['Age'].fillna(df['Age'].median())

# %%
df.isnull().sum()
# Out:
# Student    0
# Age        0
# Marks      2
# City       2
# dtype: int64

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("pokeman.csv")

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# ## write a cmd to list of all columns

# %%
df.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
df=df[['Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense','Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary']]

# %%
df.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0              Bulbasaur  Grass  Poison    318  45      49       49       65
# 1                Ivysaur  Grass  Poison    405  60      62       63       80
# 2               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        800 non-null    object
#  1   Type 1      800 non-null    object
#  2   Type 2      414 non-null    object
#  3   Total       800 non-null    int64
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
df.isnull().sum()
# Out:
# Name            0
# Type 1          0
# Type 2        386
# Total           0
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#            Name  Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 4    Charmander    Fire    NaN    309   39      52       43       60       50
# 5    Charmeleon    Fire    NaN    405   58      64       58       80       65
# 9      Squirtle   Water    NaN    314   44      48       65       50       64
# 10    Wartortle   Water    NaN    405   59      63       80       65       80
# 11    Blastoise   Water    NaN    530   79      83      100       85      105
# ..          ...     ...    ...    ...  ...     ...      ...      ...      ...
# 775     Sliggoo  Dragon    NaN    452   68      75       53       83      113
# 776      Goodra  Dragon    NaN    600   90     100       70      110      150
# 788    Bergmite     Ice    NaN    304   55      69       85       32       35
# 789     Avalugg     Ice    NaN    514   95     117      184       44       46
# 792     Xerneas   Fairy    NaN    680  126     131       95      131       98
#
# ...

# %%
df['Type 1'].value_counts() # it returns the different value as in number form
# Out:
# Type 1
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Rock         44
# Electric     44
# Ground       32
# Ghost        32
# Dragon       32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: count, dtype: int64

# %%
df["Type 1"].value_counts().plot(kind='pie' , autopct = '%1.1f%%' , cmap = 'tab20c' , figsize=(10,10))
# Out:
# <Axes: ylabel='count'>

# %%
df['Type 2'].value_counts()
# Out:
# Type 2
# Flying      97
# Ground      35
# Poison      34
# Psychic     33
# Fighting    26
# Grass       25
# Fairy       23
# Steel       22
# Dark        20
# Dragon      18
# Ice         14
# Rock        14
# Water       14
# Ghost       14
# Fire        12
# Electric     6
# Normal       4
# Bug          3
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#            Total          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.00000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   435.10250   69.258750   79.001250   73.842500   72.820000   71.902500
# std    119.96304   25.534669   32.457366   31.183501   32.722294   27.828916
# min    180.00000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    330.00000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    450.00000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    515.00000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    780.00000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
df['Total'].describe()
# Out:
# count    800.00000
# mean     435.10250
# std      119.96304
# min      180.00000
# 25%      330.00000
# 50%      450.00000
# 75%      515.00000
# max      780.00000
# Name: Total, dtype: float64

# %%
df['Total'].plot(kind = 'box' , vert = False )
# Out:
# <Axes: >

# %%
df['Legendary'].value_counts().plot(kind='pie',autopct='%1.1f%%',cmap='tab20c',figsize=(10,10))
# Out:
# <Axes: ylabel='count'>

# %%
(df.loc[df['Attack']>150]).head()
# Out:
#                         Name   Type 1    Type 2  Total   HP  Attack  Defense  \
# 137        PinsirMega Pinsir      Bug    Flying    600   65     155      120
# 141    GyaradosMega Gyarados    Water      Dark    640   95     155      109
# 163      MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190      100
# 232  HeracrossMega Heracross      Bug  Fighting    600   80     185      115
# 268  TyranitarMega Tyranitar     Rock      Dark    700  100     164      150
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 137       65       90    105           1      False
# 141       70      130     81           1      False
# 163      154      100    130           1       True
# 232       40      105     75           2      False
# 268       95      120     71           2      False

# %%
(df.loc[df['Attack']>150]).shape
# Out:
# (18, 12)

# %%
df.loc[df['Speed']<=10] ##its based upon above
# Out:
#           Name  Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 230    Shuckle     Bug   Rock    505   20      10      230       10      230
# 359   Trapinch  Ground    NaN    290   45     100       45       45       45
# 486     Bonsly    Rock    NaN    290   50      80       95       10       45
# 495   Munchlax  Normal    NaN    390  135      85       40       40       85
# 658  Ferroseed   Grass  Steel    305   44      50       91       24       86
#
#      Speed  Generation  Legendary
# 230      5           2      False
# 359     10           3      False
# 486     10           4      False
# 495      5           4      False
# 658     10           5      False

# %%
(df.loc[df['Speed']<=10]).count()
# Out:
# Name          5
# Type 1        5
# Type 2        2
# Total         5
# HP            5
# Attack        5
# Defense       5
# Sp. Atk       5
# Sp. Def       5
# Speed         5
# Generation    5
# Legendary     5
# dtype: int64

# %% [markdown]
# ## how many pokeman have a speciaf defence value of 25 or less

# %%
df.loc[df['Sp. Def']<=25]
# Out:
#                    Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 13             Caterpie      Bug     NaN    195   45      30       35
# 14              Metapod      Bug     NaN    205   50      20       55
# 16               Weedle      Bug  Poison    195   40      35       30
# 17               Kakuna      Bug  Poison    205   45      25       50
# 44           Jigglypuff   Normal   Fairy    270  115      45       20
# 97             Shellder    Water     NaN    305   30      65      100
# 106              Krabby    Water     NaN    325   30     105       90
# 125              Horsea    Water     NaN    295   30      40       70
# 139            Magikarp    Water     NaN    200   20      10       55
# 188           Igglybuff   Normal   Fairy    210   90      30       15
# 209              Wooper    Water  Ground    210   55      45       45
# 289             Silcoon      Bug     NaN    205   50      35       55
# ...

# %%
(df.loc[df['Sp. Def']<=25]).count()
# Out:
# Name          18
# Type 1        18
# Type 2         6
# Total         18
# HP            18
# Attack        18
# Defense       18
# Sp. Atk       18
# Sp. Def       18
# Speed         18
# Generation    18
# Legendary     18
# dtype: int64

# %%
(df.loc[df['Sp. Def']<=25]).shape
# Out:
# (18, 12)

# %% [markdown]
# ## Display only the legendary pokemon list

# %%
df['Legendary'].sum()
# Out:
# np.int64(65)

# %%
df.loc[df['Legendary']==True]
# Out:
#                     Name    Type 1    Type 2  Total   HP  Attack  Defense  \
# 156             Articuno       Ice    Flying    580   90      85      100
# 157               Zapdos  Electric    Flying    580   90      90       85
# 158              Moltres      Fire    Flying    580   90     100       90
# 162               Mewtwo   Psychic       NaN    680  106     110       90
# 163  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190      100
# ..                   ...       ...       ...    ...  ...     ...      ...
# 795              Diancie      Rock     Fairy    600   50     100      150
# 796  DiancieMega Diancie      Rock     Fairy    700   50     160      110
# 797  HoopaHoopa Confined   Psychic     Ghost    600   80     110       60
# 798   HoopaHoopa Unbound   Psychic      Dark    680   80     160       60
# 799            Volcanion      Fire     Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# ## find the pokemon that is clearly an outlier in terms of attack/defence

# %%
ax=sns.scatterplot(data=df,x="Defense",y="Attack")
ax.annotate("who this guy?",xy=(228,10),xytext=(150,10),color="red",
            arrowprops=dict(arrowstyle="->",color="black"))
# Out:
# Text(150, 10, 'who this guy?')

# %% [markdown]
# ## write a cmd to sort the data by defence

# %%
df.head()
# Out:
#                     Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0              Bulbasaur  Grass  Poison    318  45      49       49       65
# 1                Ivysaur  Grass  Poison    405  60      62       63       80
# 2               Venusaur  Grass  Poison    525  80      82       83      100
# 3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123      122
# 4             Charmander   Fire     NaN    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
df.sort_values(by="Defense").head()
# Out:
#           Name   Type 1 Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 121    Chansey   Normal    NaN    450  250       5        5       35      105
# 488    Happiny   Normal    NaN    220  100       5        5       15       65
# 261    Blissey   Normal    NaN    540  255      10       10       75      135
# 68        Abra  Psychic    NaN    310   25      20       15      105       55
# 188  Igglybuff   Normal  Fairy    210   90      30       15       40       20
#
#      Speed  Generation  Legendary
# 121     50           1      False
# 488     30           4      False
# 261     55           2      False
# 68      90           1      False
# 188     15           2      False

# %% [markdown]
# ## how many fire-flying pokemans are there?

# %%
(df['Type 1']=="Flying").sum()
# Out:
# np.int64(4)

# %%
(df['Type 1']=="Fire").sum()
# Out:
# np.int64(52)

# %%
df['Type 2'].value_counts()
# Out:
# Type 2
# Flying      97
# Ground      35
# Poison      34
# Psychic     33
# Fighting    26
# Grass       25
# Fairy       23
# Steel       22
# Dark        20
# Dragon      18
# Ice         14
# Rock        14
# Water       14
# Ghost       14
# Fire        12
# Electric     6
# Normal       4
# Bug          3
# Name: count, dtype: int64

# %%
df.loc[
    (df['Type 1']=='Fire')&
    (df['Type 2']=='Flying')
]
# Out:
#                           Name Type 1  Type 2  Total   HP  Attack  Defense  \
# 6                    Charizard   Fire  Flying    534   78      84       78
# 8    CharizardMega Charizard Y   Fire  Flying    634   78     104       78
# 158                    Moltres   Fire  Flying    580   90     100       90
# 270                      Ho-oh   Fire  Flying    680  106     130       90
# 730                Fletchinder   Fire  Flying    382   62      73       55
# 731                 Talonflame   Fire  Flying    499   78      81       71
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 6        109       85    100           1      False
# 8        159      115    100           1      False
# 158      125       85     90           1       True
# 270      110      154     90           2       True
# 730       56       52     84           6      False
# 731       74       69    126           6      False

# %%
((df['Type 1']=='Fire')&
    (df['Type 2']=='Flying')).sum()
# Out:
# np.int64(6)
